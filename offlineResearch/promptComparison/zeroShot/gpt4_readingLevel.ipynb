# %%
import pandas as pd
import os
import readability

# %%
# load all files from data folder (generated in Google Colab)
dfs = []
for file in os.listdir('./generatedDataFromGoogleDrive_gpt4/data/'):
    if '.csv' in file:
        temp = pd.read_csv(f'./generatedDataFromGoogleDrive_gpt4/data/{file}')
        dfs.append(temp)

# %%
# put all dfs together
all_dataframes = pd.concat(dfs)
print(len(all_dataframes))
# Out:
# 19

# %%
all_dataframes
# Out:
#                                               report  needs
# 0                                              heard  unmet
# 1   and has not engaged with staff or peers as be...  unmet
# 0                                            settled    met
# 1   afterward. Updated care plan to include sched...    met
# 0                            quite comfortable today    met
# 1   with no new pain complaints. Oxygen saturatio...    met
# 0  Resident A, 80 y/o female, experiencing unmana...  unmet
# 1  Resident B, 76 y/o male, showing signs of seve...  unmet
# 2  Resident C, 82 y/o female, diagnosed with adva...  unmet
# 3  Resident D, 79 y/o male, with advanced COPD wo...  unmet
# 4  Resident E, 85 y/o female, presents with unman...  unmet
# 0                                        Journalized    met
# 1   less today; encouraging words and presence pr...    met
# 0                                           hopeless  unmet
# 1                                               and   unmet
# 2                                tired of this pain.  unmet
# 3   Further pain management and psychological sup...  unmet
# 4            I don't have the energy to eat anymore.  unmet
# 5   Persistent nausea after meals despite antieme...  unmet

# %%
# readability - gpt3
long_text = ""
for report in all_dataframes['report']:
    report = report.replace('.', '.\n')
    long_text += report + '\n'

results = readability.getmeasures(long_text, lang='en')
# SMOG used for health - sixth grade level is good for most health documents
# https://www.tandfonline.com/doi/abs/10.1080/19325037.2008.10599016 
# https://www.rcpe.ac.uk/journal/issue/journal_40_4/fitzsimmons.pdf 
print(f'SMOG: {results['readability grades']['SMOGIndex']}')
# 10.32 result is similar to the findings of nursing ICU notes in https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6568110/
# Out:
# SMOG: 11.699529767856315
