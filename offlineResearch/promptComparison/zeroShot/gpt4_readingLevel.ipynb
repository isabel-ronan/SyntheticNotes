# %%
import pandas as pd
import os
import readability

# %%
# load all files from data folder (generated in Google Colab)
dfs = []
for file in os.listdir('./generatedDataFromGoogleDrive_gpt4/data/'):
    if '.csv' in file:
        temp = pd.read_csv(f'./generatedDataFromGoogleDrive_gpt4/data/{file}')
        dfs.append(temp)

# %%
# put all dfs together
all_dataframes = pd.concat(dfs)
print(len(all_dataframes))
# Out:
# 224

# %%
all_dataframes
# Out:
#                                                report  needs
# 0     Ms. Evelyn J. required full assistance this ...    met
# 1   Mr. George K. was slightly agitated today, fre...    met
# 2   Ms. Dorothy L. experienced tightness of breath...    met
# 3   Mr. Harold M. showed apathy and restlessness l...    met
# 4   Ms. Vivian S. faced notable difficulty with ea...    met
# ..                                                ...    ...
# 15  The resident required full assistance with dre...  unmet
# 16  Helped the resident shower and clean dental pr...  unmet
# 17  Reported that the resident was restless and wa...  unmet
# 18  The resident showed signs of severe fatigue an...  unmet
# 19  Resident needed considerable help with morning...  unmet
#
# [224 rows x 2 columns]

# %%
# readability - gpt3
long_text = ""
for report in all_dataframes['report']:
    report = report.replace('.', '.\n')
    long_text += report + '\n'

results = readability.getmeasures(long_text, lang='en')
# SMOG used for health - sixth grade level is good for most health documents
# https://www.tandfonline.com/doi/abs/10.1080/19325037.2008.10599016 
# https://www.rcpe.ac.uk/journal/issue/journal_40_4/fitzsimmons.pdf 
print(f'SMOG: {results['readability grades']['SMOGIndex']}, indicating 10th grade reading level (similar to findings in literature).')
# 10.32 result is similar to the findings of nursing ICU notes in https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6568110/
# Out:
# SMOG: 12.861594056966569, indicating 10th grade reading level (similar to findings in literature).
