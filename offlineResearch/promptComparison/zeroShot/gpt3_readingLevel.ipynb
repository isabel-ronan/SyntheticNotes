# %%
import pandas as pd
import os
import readability

# %%
# load all files from data folder (generated in Google Colab)
dfs = []
for file in os.listdir('./generatedDataFromGoogleDrive_gpt3/data/'):
    if '.csv' in file:
        temp = pd.read_csv(f'./generatedDataFromGoogleDrive_gpt3/data/{file}')
        dfs.append(temp)

# %%
# put all dfs together
all_dataframes = pd.concat(dfs)
print(len(all_dataframes))
# Out:
# 100

# %%
all_dataframes
# Out:
#                                                report  needs
# 0   Resident A is exhibiting signs of increased pa...  unmet
# 1   Resident B is experiencing frequent episodes o...  unmet
# 2   Resident C is showing signs of spiritual distr...  unmet
# 3   Resident D is displaying signs of emotional di...  unmet
# 4   Resident E is struggling with decision-making ...  unmet
# ..                                                ...    ...
# 10  1. Resident A expressed feeling anxious and ov...  unmet
# 11  2. Resident B appeared withdrawn and tearful d...  unmet
# 12  3. Resident C reported feeling fatigued and sh...  unmet
# 13  4. Resident D displayed signs of distress and ...  unmet
# 14  5. Resident E exhibited signs of confusion and...  unmet
#
# [100 rows x 2 columns]

# %%
# readability - gpt3
long_text = ""
for report in all_dataframes['report']:
    report = report.replace('.', '.\n')
    long_text += report + '\n'

results = readability.getmeasures(long_text, lang='en')
# SMOG used for health - sixth grade level is good for most health documents
# https://www.tandfonline.com/doi/abs/10.1080/19325037.2008.10599016 
# https://www.rcpe.ac.uk/journal/issue/journal_40_4/fitzsimmons.pdf 
print(f'SMOG: {results['readability grades']['SMOGIndex']}')
# 10.32 result is similar to the findings of nursing ICU notes in https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6568110/
# Out:
# SMOG: 12.829359806182485
