# %%
import pandas as pd
import os
import readability

# %%
# load all files from data folder (generated in Google Colab)
dfs = []
for file in os.listdir('./generatedDataFromGoogleDrive_gpt3/data/'):
    if '.csv' in file:
        temp = pd.read_csv(f'./generatedDataFromGoogleDrive_gpt3/data/{file}')
        dfs.append(temp)

# %%
# put all dfs together
all_dataframes = pd.concat(dfs)
print(len(all_dataframes))
# Out:
# 50

# %%
all_dataframes
# Out:
#                                               report  needs
# 0  John seemed to be in good spirits and enjoyed ...    met
# 1  Later in the day, John had a physiotherapy ses...    met
# 2  Overall, John had a good day with his shower, ...    met
# 3  John enjoyed his lunch at the canteen, savorin...    met
# 4  It's great to hear that John had a good day, a...    met
# 0  It may be a good idea for Billy to speak with ...  unmet
# 1  It may be helpful for Billy to consult with a ...  unmet
# 2  It might be a good idea for Billy to schedule ...  unmet
# 3  Billy should consider consulting with a medica...  unmet
# 4  It may be beneficial for Billy to schedule an ...  unmet
# 0  Sarah is thrilled with the progress she has be...    met
# 1  Overall, Sarah is pleased with the update from...    met
# 2  Sarah felt relieved after her appointment, kno...    met
# 3  Sarah was thrilled with the news and is determ...    met
# 4  Sarah was thrilled with the news from her GP, ...    met
# 0  Further assessment is needed to determine the ...  unmet
# 1  It is important for the GP to review Stephen's...  unmet
# 2  Based on the information provided, it seems li...  unmet
# 3  It is important for the GP to review Stephen t...  unmet
# 4  Stephen should be referred for further assessm...  unmet
# 0  After the sing song, Michael's family brought ...    met
# 1  His children brought him a cake and some prese...    met
# 2  Afterwards, they all enjoyed some cake and cof...    met
# 3  After the sing song, his family surprised him ...    met
# 4   After the sing song, they all enjoyed a delic...    met
# 0  It sounds like Andrea may be experiencing seve...  unmet
# 1  It sounds like Andrea may be experiencing seve...  unmet
# 2  It's important for Andrea to rest and stay hyd...  unmet
# 3  It sounds like Andrea is experiencing severe s...  unmet
# 4  It sounds like Andrea is experiencing severe n...  unmet
# 0  Rachel's day has been productive and engaging ...    met
# 1  Rachel's morning routine included assistance w...    met
# 2  Overall, Rachel had a busy day with various ac...    met
# 3  Overall, Rachel had a busy and productive day ...    met
# 4  Rachel's day started with receiving assistance...    met
# 0  The wound care team will be closely monitoring...  unmet
# 1  Louise's wound will be closely monitored for s...  unmet
# 2  Louise will need regular monitoring and wound ...  unmet
# 3  The wound care team will continue to monitor L...  unmet
# 4  Louise will continue to receive regular wound ...  unmet
# 0  The family has also been provided with resourc...    met
# 1  The family conference was emotional but ultima...    met
# 2  The family has been educated on what to expect...    met
# 3  The team is closely monitoring Darragh's sympt...    met
# 4  The family has been provided with information ...    met
# 0  Thank you for sharing this information. It's i...  unmet
# 1  Additionally, the healthcare assistant observe...  unmet
# 2  It is important for Michelle to follow the rec...  unmet
# 3  The healthcare team will closely monitor Miche...  unmet
# 4  The healthcare assistant will continue to moni...  unmet

# %%
# readability - gpt3
long_text = ""
for report in all_dataframes['report']:
    report = report.replace('.', '.\n')
    long_text += report + '\n'

results = readability.getmeasures(long_text, lang='en')
# SMOG used for health - sixth grade level is good for most health documents
# https://www.tandfonline.com/doi/abs/10.1080/19325037.2008.10599016 
# https://www.rcpe.ac.uk/journal/issue/journal_40_4/fitzsimmons.pdf 
print(f'SMOG: {results['readability grades']['SMOGIndex']}.')
# 10.32 result is similar to the findings of nursing ICU notes in https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6568110/
# Out:
# SMOG: 12.802505236463334.
