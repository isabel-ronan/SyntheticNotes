# %%
import pandas as pd
import os
import readability

# %%
# load all files from data folder (generated in Google Colab)
dfs = []
for file in os.listdir('./generatedDataFromGoogleDrive_gpt4/data/'):
    if '.csv' in file:
        temp = pd.read_csv(f'./generatedDataFromGoogleDrive_gpt4/data/{file}')
        dfs.append(temp)

# %%
# put all dfs together
all_dataframes = pd.concat(dfs)
print(len(all_dataframes))
# Out:
# 25

# %%
all_dataframes
# Out:
#                                               report  needs
# 0  It sounds like John had a relatively good day ...    met
# 1  It sounds like John had a reasonably good day....    met
# 0  It sounds like Sarah's recovery is progressing...    met
# 1  It sounds like Sarah's recovery is going well....    met
# 2  That's great news about Sarah's progress! It s...    met
# 3  That's great news about Sarah's progress! The ...    met
# 4  It's great to hear that Sarah's GP appointment...    met
# 0  Stephen reported experiencing significant pain...  unmet
# 1  It sounds like Stephen is experiencing signifi...  unmet
# 2  It sounds like Stephen is experiencing signifi...  unmet
# 0  It sounds like Michael had a wonderful day! He...    met
# 1  That sounds like a wonderful day for Michael! ...    met
# 2  It sounds like Michael had a wonderful day cel...    met
# 3  It sounds like Michael had a wonderful day! Sh...    met
# 4  It sounds like Michael had a wonderful and ful...    met
# 0  Andrea experienced nausea during lunch today, ...  unmet
# 1  Andrea experienced nausea during lunch today, ...  unmet
# 2  Andrea experienced nausea during lunch today. ...  unmet
# 0  It sounds like Rachel had a very active and we...    met
# 0  It sounds like Louise received routine morning...  unmet
# 1  It sounds like Louise received assistance with...  unmet
# 2  It sounds like Louise received assistance with...  unmet
# 3  It was reported that Louise was assisted with ...  unmet
# 0  It sounds like Michelle is experiencing diffic...  unmet
# 1  It sounds like you've already taken some proac...  unmet

# %%
# readability - gpt3
long_text = ""
for report in all_dataframes['report']:
    report = report.replace('.', '.\n')
    long_text += report + '\n'

results = readability.getmeasures(long_text, lang='en')
# SMOG used for health - sixth grade level is good for most health documents
# https://www.tandfonline.com/doi/abs/10.1080/19325037.2008.10599016 
# https://www.rcpe.ac.uk/journal/issue/journal_40_4/fitzsimmons.pdf 
print(f'SMOG: {results['readability grades']['SMOGIndex']}.')
# 10.32 result is similar to the findings of nursing ICU notes in https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6568110/
# Out:
# SMOG: 12.66804397901485.
