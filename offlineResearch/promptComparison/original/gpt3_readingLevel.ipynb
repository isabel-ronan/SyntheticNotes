# %%
import pandas as pd
import os
import readability

# %%
# load all files from data folder (generated in Google Colab)
dfs = []
for file in os.listdir('./generatedDataFromGoogleDrive_gpt3/data/'):
    if '.csv' in file:
        temp = pd.read_csv(f'./generatedDataFromGoogleDrive_gpt3/data/{file}')
        dfs.append(temp)

# %%
# put all dfs together
all_dataframes = pd.concat(dfs)
print(len(all_dataframes))
# Out:
# 234

# %%
all_dataframes
# Out:
#                                                report  needs
# 0   Samantha received a salt bath this morning to ...    met
# 1   Thomas showed signs of discomfort during his m...    met
# 2   Emily experienced an increase in pain levels t...    met
# 3   Michael had a restless night and woke up fatig...    met
# 4   Sophia had a difficult day with increased naus...    met
# ..                                                ...    ...
# 20  Mr. Smith complained of severe back pain durin...  unmet
# 21  Mrs. Johnson exhibited signs of restlessness a...  unmet
# 22  Mr. Brown experienced nausea and vomiting afte...  unmet
# 23  Mrs. Williams reported persistent shortness of...  unmet
# 24  Mr. Davis displayed signs of confusion and dis...  unmet
#
# [234 rows x 2 columns]

# %%
# readability - gpt3
long_text = ""
for report in all_dataframes['report']:
    report = report.replace('.', '.\n')
    long_text += report + '\n'

results = readability.getmeasures(long_text, lang='en')
# SMOG used for health - sixth grade level is good for most health documents
# https://www.tandfonline.com/doi/abs/10.1080/19325037.2008.10599016 
# https://www.rcpe.ac.uk/journal/issue/journal_40_4/fitzsimmons.pdf 
print(f'SMOG: {results['readability grades']['SMOGIndex']}, indicating 10th grade reading level (similar to findings in literature).')
# 10.32 result is similar to the findings of nursing ICU notes in https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6568110/
# Out:
# SMOG: 11.493293718349644, indicating 10th grade reading level (similar to findings in literature).
